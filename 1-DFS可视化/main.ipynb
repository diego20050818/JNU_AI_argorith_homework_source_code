# %%
import matplotlib.pyplot as plt
import networkx as nx
import time
from rich import print as rprint
import sys

# %%
#定义有向图
city_graph = {
    '广州': ['珠海', '香港', '上海', '杭州','蒙德'],  
    '珠海': ['广州', '香港', '深圳', '澳门'],
    '北京': ['上海', '杭州', '广州', '香港'],
    '上海': ['北京', '杭州', '广州', '深圳'],
    '杭州': ['北京', '上海', '广州', '苏州'],
    '香港': ['广州', '珠海', '深圳', '澳门'],
    '深圳': ['珠海', '香港', '广州', '上海'],
    '澳门': ['珠海', '香港','翁法罗斯'],
    '尼伯龙根': ['蒙德', '贝洛伯格', '稻妻'],
    '蒙德': ['尼伯龙根', '贝洛伯格', '圣芙蕾雅','广州'], 
    '贝洛伯格': ['尼伯龙根', '蒙德', '稻妻'],
    '稻妻': ['尼伯龙根', '贝洛伯格', '圣芙蕾雅'],
    '圣芙蕾雅': ['蒙德', '稻妻', '罗浮'],
    '罗浮': ['圣芙蕾雅', '匹诺康尼', '翁法罗斯'],
    '匹诺康尼': ['罗浮', '翁法罗斯'],
    '翁法罗斯': ['罗浮', '匹诺康尼'],
    '苏州': ['杭州', '上海'],
    '成都': ['广州', '北京', '上海'],
    '重庆': ['成都', '上海', '深圳'],
    '武汉': ['北京', '广州', '上海'],
    '南京': ['上海', '杭州', '苏州']
}

# %%
#定义起始点和目的地
start = '南京'
end = '北京'
#stack = [(start,[start])]
#visited = set()
#all_path = []
path = []
stack = []

count_range = 0

def dfs_search_path(point=start, end=end, G=city_graph):
    global count_range
    count_range += 1
    stack.append(point)
    if point == end:
        print(f"寻找到从{start}到{end}的路径:",end="")
        for i in stack[:len(stack)-1]:
            print(i+" -> ",end="")
        print(stack[len(stack)-1],end="")
        
        path.append(list(stack))
        stack.pop()
        print(f"   迭代次数：{count_range}")
        return
    for neighbor in G[point]:
        if neighbor not in stack:
            dfs_search_path(neighbor, end, G)
    stack.pop()
    print(f"正在寻找路径：{stack}",end="\r")
    sys.stdout.flush()
    #time.sleep(0.01)
    
    

try: 
    dfs_search_path()
    count = []
    for i in path:
        count.append(len(i))
    min_index = count.index(min(count))
    #print(f"{start}到{end}最短路径为{path[min_index]},长度为{len(path[min_index])-1}")
    min_path = ""
    for j in path[min_index][:len(path[min_index])-1]:
        min_path += f"{j} -> "
    min_path += end
    print(f"\n找到{len(path)}条路径")
    print(f"{start}到{end}最短路径为{min_path},长度为{len(path[min_index])-1}")
except Exception as e:
    print(f"输入图像不是全连通图或者{e}")
# Out:
# 寻找到从南京到北京的路径:南京 -> 上海 -> 北京   迭代次数：3
# 寻找到从南京到北京的路径:南京 -> 上海 -> 杭州 -> 北京   迭代次数：5
# 寻找到从南京到北京的路径:南京 -> 上海 -> 广州 -> 杭州 -> 北京   迭代次数：708尼'] '罗浮'] '圣芙蕾雅'] '稻妻'] '贝洛伯格'] '蒙德']']伯格'] '蒙德']']蒙德']']
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 珠海 -> 广州 -> 杭州 -> 北京   迭代次数：813尼'] '罗浮'] '圣芙蕾雅'] '稻妻'] '贝洛伯格'] '蒙德']']
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 珠海 -> 香港 -> 广州 -> 杭州 -> 北京   迭代次数：864浮'] '翁法罗斯'] '翁法罗斯']
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 珠海 -> 香港 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：929
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 珠海 -> 香港 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：937
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 珠海 -> 香港 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：943
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 珠海 -> 香港 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：950
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 珠海 -> 香港 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：956
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 珠海 -> 香港 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：975
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 珠海 -> 香港 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：983
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 珠海 -> 香港 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：989
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 珠海 -> 香港 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：996
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 珠海 -> 香港 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1002
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 珠海 -> 澳门 -> 香港 -> 广州 -> 杭州 -> 北京   迭代次数：1008稻妻'] '贝洛伯格'] '蒙德'] '广州'] '杭州']
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 珠海 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1073']
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 珠海 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1082
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 珠海 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1089
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 珠海 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1097
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 珠海 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1104
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 珠海 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1124
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 珠海 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1133
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 珠海 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1140
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 珠海 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1148
# 寻找到从南京到北京的路径: '上海', '深圳', '珠海', '澳门', '翁法罗斯', '匹诺康尼', '罗浮', '圣芙蕾雅', '稻妻', '贝洛伯格', '蒙德', '广州']'] '广州'] '杭州']南京 -> 上海 -> 深圳 -> 珠海 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1155
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 香港 -> 广州 -> 杭州 -> 北京   迭代次数：1213'] '罗浮'] '圣芙蕾雅'] '稻妻'] '贝洛伯格'] '蒙德']']
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 香港 -> 珠海 -> 广州 -> 杭州 -> 北京   迭代次数：1264'] '翁法罗斯'] '翁法罗斯']
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 香港 -> 珠海 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1329
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 香港 -> 珠海 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1337
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 香港 -> 珠海 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1343
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 香港 -> 珠海 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1350
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 香港 -> 珠海 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1356
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 香港 -> 珠海 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1375
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 香港 -> 珠海 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1383
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 香港 -> 珠海 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1389
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 香港 -> 珠海 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1396
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 香港 -> 珠海 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1402
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 香港 -> 澳门 -> 珠海 -> 广州 -> 杭州 -> 北京   迭代次数：1408稻妻'] '贝洛伯格'] '蒙德'] '广州'] '杭州']
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 香港 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1473']
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 香港 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1482
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 香港 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1489
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 香港 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1497
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 香港 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1504
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 香港 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1524
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 香港 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1533
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 香港 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1540
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 香港 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1548
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 香港 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：1555
# 寻找到从南京到北京的路径:南京 -> 上海 -> 深圳 -> 广州 -> 杭州 -> 北京   迭代次数：1773'] '罗浮'] '圣芙蕾雅'] '稻妻'] '贝洛伯格'] '蒙德']']蒙德']']
# 寻找到从南京到北京的路径:南京 -> 杭州 -> 北京   迭代次数：1822圣芙蕾雅'] '罗浮'] '翁法罗斯'] '罗浮'] '翁法罗斯'] '翁法罗斯']
# 寻找到从南京到北京的路径:南京 -> 杭州 -> 上海 -> 北京   迭代次数：1824
# 寻找到从南京到北京的路径:南京 -> 杭州 -> 广州 -> 珠海 -> 香港 -> 深圳 -> 上海 -> 北京   迭代次数：3127'] '翁法罗斯'] '翁法罗斯']贝洛伯格'] '蒙德']']蒙德']']
# 寻找到从南京到北京的路径:南京 -> 杭州 -> 广州 -> 珠海 -> 深圳 -> 上海 -> 北京   迭代次数：3235'] '罗浮'] '圣芙蕾雅'] '稻妻'] '贝洛伯格'] '蒙德']']
# 寻找到从南京到北京的路径:南京 -> 杭州 -> 广州 -> 珠海 -> 澳门 -> 香港 -> 深圳 -> 上海 -> 北京   迭代次数：3240
# 寻找到从南京到北京的路径:南京 -> 杭州 -> 广州 -> 香港 -> 珠海 -> 深圳 -> 上海 -> 北京   迭代次数：3296稻妻'] '贝洛伯格'] '蒙德']']
# 寻找到从南京到北京的路径:南京 -> 杭州 -> 广州 -> 香港 -> 深圳 -> 上海 -> 北京   迭代次数：3404'] '罗浮'] '圣芙蕾雅'] '稻妻'] '贝洛伯格'] '蒙德']']
# 寻找到从南京到北京的路径:南京 -> 杭州 -> 广州 -> 香港 -> 澳门 -> 珠海 -> 深圳 -> 上海 -> 北京   迭代次数：3409
# 寻找到从南京到北京的路径:南京 -> 杭州 -> 广州 -> 上海 -> 北京   迭代次数：3462'] '罗浮'] '圣芙蕾雅'] '稻妻'] '贝洛伯格'] '蒙德']']
# 寻找到从南京到北京的路径:南京 -> 杭州 -> 苏州 -> 上海 -> 北京   迭代次数：3726'] '罗浮'] '翁法罗斯'] '翁法罗斯']蕾雅'] '稻妻'] '贝洛伯格'] '蒙德']']蒙德']']
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 杭州 -> 北京   迭代次数：5026蒙德'] '圣芙蕾雅'] '罗浮'] '翁法罗斯'] '罗浮'] '翁法罗斯'] '翁法罗斯']贝洛伯格'] '蒙德']']蒙德']']
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 杭州 -> 上海 -> 北京   迭代次数：5028
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 杭州 -> 广州 -> 珠海 -> 香港 -> 深圳 -> 上海 -> 北京   迭代次数：6331'] '翁法罗斯'] '翁法罗斯']贝洛伯格'] '蒙德']']蒙德']']
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 杭州 -> 广州 -> 珠海 -> 深圳 -> 上海 -> 北京   迭代次数：6439'] '罗浮'] '圣芙蕾雅'] '稻妻'] '贝洛伯格'] '蒙德']']
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 杭州 -> 广州 -> 珠海 -> 澳门 -> 香港 -> 深圳 -> 上海 -> 北京   迭代次数：6444
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 杭州 -> 广州 -> 香港 -> 珠海 -> 深圳 -> 上海 -> 北京   迭代次数：6500稻妻'] '贝洛伯格'] '蒙德']']
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 杭州 -> 广州 -> 香港 -> 深圳 -> 上海 -> 北京   迭代次数：6608'] '罗浮'] '圣芙蕾雅'] '稻妻'] '贝洛伯格'] '蒙德']']
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 杭州 -> 广州 -> 香港 -> 澳门 -> 珠海 -> 深圳 -> 上海 -> 北京   迭代次数：6613
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 杭州 -> 广州 -> 上海 -> 北京   迭代次数：6666'] '罗浮'] '圣芙蕾雅'] '稻妻'] '贝洛伯格'] '蒙德']']
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 北京   迭代次数：6929 '罗浮'] '翁法罗斯'] '罗浮'] '翁法罗斯'] '翁法罗斯']蕾雅'] '稻妻'] '贝洛伯格'] '蒙德']']蒙德']']
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 杭州 -> 北京   迭代次数：6931
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 广州 -> 杭州 -> 北京   迭代次数：7633'] '罗浮'] '圣芙蕾雅'] '稻妻'] '贝洛伯格'] '蒙德']']伯格'] '蒙德']']蒙德']']
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 珠海 -> 广州 -> 杭州 -> 北京   迭代次数：7737'] '罗浮'] '圣芙蕾雅'] '稻妻'] '贝洛伯格'] '蒙德']']
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 珠海 -> 香港 -> 广州 -> 杭州 -> 北京   迭代次数：7787'] '翁法罗斯'] '翁法罗斯']
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 珠海 -> 香港 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：7851
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 珠海 -> 香港 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：7858
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 珠海 -> 香港 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：7863
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 珠海 -> 香港 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：7869
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 珠海 -> 香港 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：7874
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 珠海 -> 香港 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：7892
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 珠海 -> 香港 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：7899
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 珠海 -> 香港 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：7904
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 珠海 -> 香港 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：7910
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 珠海 -> 香港 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：7915
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 珠海 -> 澳门 -> 香港 -> 广州 -> 杭州 -> 北京   迭代次数：7920稻妻'] '贝洛伯格'] '蒙德'] '广州']
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 珠海 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：7984']
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 珠海 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：7992
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 珠海 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：7998
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 珠海 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：8005
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 珠海 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：8011
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 珠海 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：8030
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 珠海 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：8038
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 珠海 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：8044
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 珠海 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：8051
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 珠海 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：8057
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 香港 -> 广州 -> 杭州 -> 北京   迭代次数：8114'] '罗浮'] '圣芙蕾雅'] '稻妻'] '贝洛伯格'] '蒙德']']
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 香港 -> 珠海 -> 广州 -> 杭州 -> 北京   迭代次数：8164'] '翁法罗斯'] '翁法罗斯']
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 香港 -> 珠海 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：8228
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 香港 -> 珠海 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：8235
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 香港 -> 珠海 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：8240
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 香港 -> 珠海 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：8246
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 香港 -> 珠海 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：8251
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 香港 -> 珠海 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：8269
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 香港 -> 珠海 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：8276
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 香港 -> 珠海 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：8281
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 香港 -> 珠海 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：8287
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 香港 -> 珠海 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：8292
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 香港 -> 澳门 -> 珠海 -> 广州 -> 杭州 -> 北京   迭代次数：8297稻妻'] '贝洛伯格'] '蒙德'] '广州']
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 香港 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：8361']
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 香港 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：8369
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 香港 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：8375
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 香港 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：8382
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 香港 -> 澳门 -> 翁法罗斯 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：8388
# 寻找到从南京到北京的路径: '苏州', '上海', '深圳', '香港', '澳门', '翁法罗斯', '匹诺康尼', '罗浮', '圣芙蕾雅', '蒙德', '广州']'] '稻妻']']南京 -> 苏州 -> 上海 -> 深圳 -> 香港 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：8407
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 香港 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：8415
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 香港 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 尼伯龙根 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：8421
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 香港 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 尼伯龙根 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：8428
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 香港 -> 澳门 -> 翁法罗斯 -> 匹诺康尼 -> 罗浮 -> 圣芙蕾雅 -> 稻妻 -> 贝洛伯格 -> 蒙德 -> 广州 -> 杭州 -> 北京   迭代次数：8434
# 寻找到从南京到北京的路径:南京 -> 苏州 -> 上海 -> 深圳 -> 广州 -> 杭州 -> 北京   迭代次数：8651'] '罗浮'] '圣芙蕾雅'] '稻妻'] '贝洛伯格'] '蒙德']']蒙德']']
# 正在寻找路径：[]南京'] '苏州'] '上海'] '深圳'] '广州'] '蒙德'] '圣芙蕾雅'] '罗浮'] '翁法罗斯'] '罗浮'] '翁法罗斯'] '翁法罗斯']
# 找到119条路径
# 南京到北京最短路径为南京 -> 上海 -> 北京,长度为2

# %%
#画出有向图
G = nx.DiGraph()
for city in city_graph:
    G.add_node(city)
    for neighbor in city_graph[city]:
        G.add_edge(city, neighbor)

# %%
pos = nx.spring_layout(G)


plt.figure(figsize=(12,8))
plt.title("DFS path finding",fontsize=14)

default_color = '#ffffd2'
current_color = '#a8d8ea'
visited_color = '#fcbad3'
path_color = '#aa96da'

nx.draw_networkx_nodes(G,pos,node_color=default_color)
nx.draw_networkx_edges(G,pos,alpha=0.3,edge_color=visited_color)
nx.draw_networkx_labels(G, pos, font_family='SimHei')

plt.ion()
plt.show()

# %%
def dfs_search_path_visual(point=start, end=end, G=city_graph):
    stack.append(point)
    if point == end:
        print(f"寻找到从{start}到{end}的路径: {stack}")
        path.append(list(stack))
        stack.pop()
        return
    for neighbor in G[point]:
        if neighbor not in stack:
            # 可视化当前节点和边
            nx.draw_networkx_nodes(G, pos, nodelist=[neighbor], node_color=current_color)
            nx.draw_networkx_edges(G, pos, edgelist=[(point, neighbor)], edge_color=current_color)
            plt.pause(0.5)
            dfs_search_path_visual(neighbor, end, G)
            # 恢复颜色
            nx.draw_networkx_nodes(G, pos, nodelist=[neighbor], node_color=default_color)
            nx.draw_networkx_edges(G, pos, edgelist=[(point, neighbor)], edge_color=visited_color)
            plt.pause(0.5)
    stack.pop()

# %%
# %%
import plotly.graph_objects as go
import networkx as nx

# %%
# 定义有向图
city_graph = {
    '广州': ['珠海', '香港', '上海', '杭州','蒙德'],  
    '珠海': ['广州', '香港', '深圳', '澳门'],
    '北京': ['上海', '杭州', '广州', '香港'],
    '上海': ['北京', '杭州', '广州', '深圳'],
    '杭州': ['北京', '上海', '广州', '苏州'],
    '香港': ['广州', '珠海', '深圳', '澳门'],
    '深圳': ['珠海', '香港', '广州', '上海'],
    '澳门': ['珠海', '香港'],
    '奥么恩': ['蒙德', '贝洛伯格', '稻妻'],
    '蒙德': ['奥么恩', '贝洛伯格', '圣芙蕾雅','广州'], 
    '贝洛伯格': ['奥么恩', '蒙德', '稻妻'],
    '稻妻': ['奥么恩', '贝洛伯格', '圣芙蕾雅'],
    '圣芙蕾雅': ['蒙德', '稻妻', '罗浮'],
    '罗浮': ['圣芙蕾雅', '匹诺康尼', '翁法罗斯'],
    '匹诺康尼': ['罗浮', '翁法罗斯'],
    '翁法罗斯': ['罗浮', '匹诺康尼'],
    '苏州': ['杭州', '上海'],
    '成都': ['广州', '北京', '上海'],
    '重庆': ['成都', '上海', '深圳'],
    '武汉': ['北京', '广州', '上海'],
    '南京': ['上海', '杭州', '苏州']
}

# %%
# 定义起始点和目的地
start = '广州'
end = '翁法罗斯'
path = []
stack = []

# %%
# 画出有向图
# %% 
# 修改导入部分
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.io import curdoc
from bokeh.palettes import Category20
import networkx as nx
import numpy as np

# %% 修改可视化部分
G = nx.DiGraph()
for city in city_graph:
    G.add_node(city)
    for neighbor in city_graph[city]:
        G.add_edge(city, neighbor)

pos = nx.spring_layout(G, k=2)

# 创建 Bokeh 画布
p = figure(title="DFS Path Finding", tools="pan,wheel_zoom,reset", 
          x_range=(-2, 2), y_range=(-2, 2))

# 绘制初始边
edge_source = ColumnDataSource(data={
    'xs': [],
    'ys': [],
    'colors': []
})

# 绘制节点
node_x = [pos[k][0] for k in G.nodes]
node_y = [pos[k][1] for k in G.nodes]
labels = list(G.nodes)

# 添加节点和标签
p.circle(node_x, node_y, size=15, fill_color='#ffffd2', line_color='black')
labels = LabelSet(x=node_x, y=node_y, text=labels, text_font_size='10pt',
                  x_offset=5, y_offset=5, text_color='black')
                  x_offset=5, y_offset=5, text_color='black')
p.add_layout(labels)

# 高亮起点终点
start_idx = labels.text.index(start)
end_idx = labels.text.index(end)
p.circle([node_x[start_idx], node_x[end_idx]], 
        [node_y[start_idx], node_y[end_idx]], 
        size=15, color='#66c18c')

# 动态更新函数
def update_edges(steps):
    new_data = {
        'xs': [],
        'ys': [],
        'colors': []
    }
    for step in steps:
        point, neighbor, status = step
        x0, y0 = pos[point]
        x1, y1 = pos[neighbor]
        new_data['xs'].append([x0, x1])
        new_data['ys'].append([y0, y1])
        new_data['colors'].append('#a8d8ea' if status == 'current' else '#fcbad3')
    
    edge_source.stream(new_data, rollover=1000)  # 保留最多1000条边

# 初始化渲染
edge_renderer = p.multi_line('xs', 'ys', source=edge_source, 
                            line_color='colors', line_width=2)

# 显示画布
output_notebook()
handle = show(p, notebook_handle=True)
# 修改搜索函数
def dfs_search_path(point=start, end=end, G=G):
    global steps  # 添加全局声明
    stack.append(point)
    if point == end:
        path.append(list(stack))
        stack.pop()
        return
    for neighbor in G[point]:
        if neighbor not in stack:
            steps.append((point, neighbor, 'current'))
            update_edges(steps)  # 实时更新
            dfs_search_path(neighbor, end, G)
            steps.append((point, neighbor, 'visited'))
            update_edges(steps)  # 实时更新
    stack.pop()
# 调用搜索并保持展示
steps = []  # 初始化steps数组
dfs_search_path()
def dfs_search_path(point=start, end=end, G=G):
    stack.append(point)
    if point == end:
        path.append(list(stack))
        stack.pop()
        return
    for neighbor in G[point]:
        if neighbor not in stack:
            steps.append((point, neighbor, 'current'))
            dfs_search_path(neighbor, end, G)
            steps.append((point, neighbor, 'visited'))
    stack.pop()
# 修改可视化更新逻辑
with fig.batch_update():
    fig.data = [trace for trace in fig.data if not trace.line.color]  # 保留基础布局
    for point, neighbor, status in steps:
        color = '#a8d8ea' if status == 'current' else '#ffffd2'
        x0, y0 = pos[point]
        x1, y1 = pos[neighbor]
        fig.add_trace(go.Scatter(x=[x0, x1], y=[y0, y1], mode='lines', line=dict(width=2, color=color)))
        fig.show()

dfs_search_path()
visualize_steps(steps, G, pos)

# 计算并打印最短路径
count = []
for i in path:
    count.append(len(i))
min_index = count.index(min(count))
print(f"{start}到{end}最短路径为{path[min_index]}, 长度为{len(path[min_index])-1}")
print(path)
# Out:
#   File <tokenize>:85
#     [node_y[start_idx], node_y[end_idx]],
#     ^
# IndentationError: unindent does not match any outer indentation level
